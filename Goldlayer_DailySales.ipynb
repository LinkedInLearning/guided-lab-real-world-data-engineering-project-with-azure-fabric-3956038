# %%
spark.sql("""
CREATE OR REPLACE TABLE gold_daily_sales AS
SELECT 
    transaction_date,
    SUM(total_amount) AS daily_total_sales
FROM 
    SilverLayer.silver_orders
GROUP BY 
    transaction_date
""")
# Out:
# StatementMeta(, 647f611f-ee26-4a6b-9a82-545891dbc9f8, 4, Finished, Available, Finished)
# DataFrame[]

# %%
# Verify the data in the Gold table
spark.sql("SELECT * FROM gold_daily_sales LIMIT 10").show()
# Out:
# StatementMeta(, 647f611f-ee26-4a6b-9a82-545891dbc9f8, 5, Finished, Available, Finished)
# +----------------+------------------+
# |transaction_date| daily_total_sales|
# +----------------+------------------+
# |      2021-12-18|           4502.84|
# |      2020-08-24|3680.6400000000003|
# |      2021-10-11|           1130.33|
# |      2023-06-22|3301.9200000000005|
# |      2021-08-27|1753.8000000000002|
# |      2022-03-28|           4544.17|
# |      2021-06-22|           2098.65|
# |      2021-01-27|           2907.07|
# |      2022-07-31|           3467.85|
# |      2023-07-15|           4642.21|
# +----------------+------------------+
