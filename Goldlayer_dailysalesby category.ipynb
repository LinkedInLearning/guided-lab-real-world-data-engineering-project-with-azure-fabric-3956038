# %%
spark.sql("""
CREATE OR REPLACE TABLE gold_category_sales AS
SELECT 
    p.category AS product_category,
    SUM(o.total_amount) AS category_total_sales
FROM 
    Silverlayer.silver_orders o
JOIN 
    Silverlayer.silver_products p ON o.product_id = p.product_id
GROUP BY 
    p.category
""")
# Out:
# StatementMeta(, 8d5cb1ed-2858-4542-a538-22b2cfc71300, 3, Finished, Available, Finished)
# DataFrame[]

# %%
# Verify the data in the Gold table
spark.sql("SELECT * FROM gold_category_sales LIMIT 10").show()
# Out:
# StatementMeta(, 8d5cb1ed-2858-4542-a538-22b2cfc71300, 4, Finished, Available, Finished)
# +----------------+--------------------+
# |product_category|category_total_sales|
# +----------------+--------------------+
# |            Home|   456502.7899999996|
# |            Food|  441974.49999999994|
# |          Sports|  510337.51999999984|
# |     Electronics|   426449.8000000001|
# |        Clothing|  519243.32999999984|
# |      Automotive|   472281.3300000003|
# |           Books|   429673.7600000005|
# |          Garden|   483605.1099999997|
# |          Beauty|   415598.3400000004|
# |            Toys|  507586.16000000015|
# +----------------+--------------------+
